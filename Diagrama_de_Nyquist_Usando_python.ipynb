# %% [markdown]
# # Aluno : Victor Calebe Cavalcante de Macedo.
# ---
# ###Lista 2 de controle 2.

# %%
# !pip install control

# %% [markdown]
# \begin{align}G(s) = \frac{1}{s-0.5}
# \end{align}

# %%
from pylab import plot
import control
from control import TransferFunction

s = TransferFunction.s
G  = (2)/(2*s - 1)
control.nyquist(G)

plot()
# Out:
# []

# %% [markdown]
# \begin{align}G(s) = \frac{1}{(s+1)(s-0.5)}
# \end{align}

# %%
G  = (1)/((s+1)*(s-0.5))
control.nyquist(G)

plot()
# Out:
# []

# %% [markdown]
# \begin{align}G(s) = \frac{s+1}{s-0.5}
# \end{align}

# %%
G  = (s+1)/(s-0.5)
control.nyquist(G)

plot()
# Out:
# []

# %% [markdown]
# \begin{align}G(s) = \frac{1}{s^{2}(s+1)(s+0.5)}
# \end{align}

# %%
G  = (1)/((s**2)*(s+1)*(s+0.5))
control.nyquist(G)

plot()
# Out:
# []

# %% [markdown]
# \begin{align}G(s) = \frac{s}{(s+1)(s+0.5)}
# \end{align}

# %%
G  = (s)/((s+1)*(s+0.5))
control.nyquist(G)

plot()
# Out:
# []
